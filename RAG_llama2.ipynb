# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravS-30/LLM/blob/main/RAG_llama2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 5.8 MB/s eta 0:00:00
# ...

# %%
hf_token = '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'

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !huggingface-cli whoami
# Out:
# Gaurav03

# %%
from transformers import AutoTokenizer
import transformers
import torch

model = 'meta-llama/Llama-2-7b-chat-hf'
tokenizer = AutoTokenizer.from_pretrained(model,use_auth_token = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:671: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
from transformers import pipeline
llama_pipeline = pipeline('text-generation',
                          model = model,
                          torch_dtype = torch.float16,
                          device_map = 'auto')
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
# !pip install -q langchain
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.4 MB/s eta 0:00:00

# %%
from langchain.llms import HuggingFacePipeline
local_llm = HuggingFacePipeline(pipeline = llama_pipeline)

# %%
print(local_llm('What is capital of Arizona'))
# Out:
# ?
#
# Answer: The capital of Arizona is Phoenix.

# %%
print(local_llm('What is RAG?'))
# Out:
# RAG (Risk, Assurance, Governance) is a framework used in project management, IT, and business to identify, assess, and manage risks. It helps organizations to identify potential risks and develop strategies to mitigate or manage them. The RAG framework is based on three categories:
#
# 1. Red (High Risk): Risks that have a high probability of occurring and could have a significant impact on the project or organization.
# 2. Amber (Medium Risk): Risks that have a moderate probability of occurring and could have a moderate impact on the project or organization.
# 3. Green (Low Risk): Risks that have a low probability of occurring and are unlikely to have a significant impact on the project or organization.
#
# By categorizing risks using the RAG framework, organizations can prioritize their risk management efforts and allocate resources more effectively. It also helps to ensure that risks are being properly managed and monitored throughout the project lifecycle.
